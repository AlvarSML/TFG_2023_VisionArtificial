# %% [markdown]
# # Script de generacion de la estructura de archivos para Perceptron2
# ---
# - Input: La carpeta enviada por el dentista
# - Output:
#     - Archivo COCO llamado "labels.json"
#     - Serie de archivos en la carpeta ./data
# ---
# ## 1. Limpieza de datos
# La idea es descartar aquellas imagnes incompletas (pone NO en la carpeta) o que no han sido segmentadas (no tienen alguno de los json)
#
# ## 2. Carga automatica
# Hay que realizar el menor trabajo a mano, por ello se queremos usar la carpeta que nos ha dado el dentista y haciendo el menor numero de cambios, cargar los datos en un direcotrio nuevo y estructurado

# %%
import json
import numpy as np
import skimage.io as io
import random
import os
import cv2
import matplotlib as mpl
import numpy as np
from datetime import datetime
import re
import shutil

# %%
coco_file = r'./Dataset/labels_init.json'  # Aqui esta el json COCO creado
org_folder = r'./Dataset/data'  
img_folder = r'./Dataset/data/'  # Directorio de imagenes procesadads en el json
raw_folder = r'./CasosOrigen'

# %%
def lee_trio(carpeta_actual):
    r""" Lee un direcorio de una radiografia y devuelve las partes utiles 
            en un diccionario {"imagen":,"json_diente":,"json_raiz":}
        - Una imagen tal que: ([0-9]+)a.jpg (Que es la sin medidor)
        - Dos archivos JSON: (CASO)([\ 0-9]+)\.(ROOT CANAL|TOOTH)\.json
    """
    with os.scandir(carpeta_actual) as dirs:
        REG_IMG = r"([0-9]+)[aA]?.jpg"
        REG_DIENTE = r"(CASO)([\ 0-9]+)\.[\ ]*TOOTH\.json"
        REG_RAIZ = r"(CASO)([\ 0-9]+)\.[\ ]*ROOT CANAL\.json"
        trio = {}
        print(f"-> Accediendo a la capeta {carpeta_actual.name} ")
        for elemento in dirs:
            if elemento.is_file():
                print(f"\t -> Analizando el elemento {elemento.name} ")
                if re.search(REG_IMG, elemento.name):
                    trio["imagen"] = elemento
                    print(f"\t\t -> introduciendo imagen {elemento.name} ")
                elif re.search(REG_DIENTE, elemento.name):
                    trio["json_diente"] = elemento
                    print(f"\t\t -> introduciendo datos diente {elemento.name} ")
                elif re.search(REG_RAIZ, elemento.name):
                    trio["json_raiz"] = elemento
                    print(f"\t\t -> introduciendo datos raiz {elemento.name} ")
        print(f"\t #En el directorio {carpeta_actual.name} hay {len(trio)} elementos")
        if (len(trio) != 3):
            print("\t!!! Faltan archivos")
        return trio


def lee_subcarpetas(raiz="./Casos"):
    """ La idea es leer una estructura tal que
        - Contenedor
            - Caso1
                - Imagen.jpg
                - Dienete.json
                - Raiz.json
            - Caso2
                - Imagen.jpg
                - Dienete.json
                - Raiz.json
        Y devolver una lista de trios [{"imagen":,"json_diente":,"json_raiz":}],
            que luego procesar

        Se ignoran las carpetas que ponga NO detras de la imagen
    """
    REG_INVALIDO = r"CASO[\ ]*[0-9]+[\ ]*NO"
    lista = []
    dirs_leidos = 0
    with os.scandir(raiz) as dirs:
        for carpeta in dirs:
            if carpeta.is_dir() and not re.search(REG_INVALIDO, carpeta.name):
                trio = lee_trio(carpeta)
                if len(trio) == 3:
                    lista.append(trio)
                    dirs_leidos = dirs_leidos + 1
        print(f"# Se han analizado {dirs_leidos} diretorios validos ")
        return lista

# %%
def gen_segmentation(x_vals, y_vals):
    """ Convierte 2 sets de valores en uno solo con X e Y intercaladas
        como es COCO viene una lista dentro de otra
    """
    seg = [[]]
    for i in range(len(x_vals)):
        seg[0].append(x_vals[i])
        seg[0].append(y_vals[i])
    return seg


def gen_bbox(x_vals, y_vals):
    """ Genera el BoundayBox de la segmentacion
    """
    return [
        min(x_vals),
        min(y_vals),
        max(x_vals),
        max(y_vals)
    ]


def gen_area(x, y):
    """ Se usa el teorema de los cordones para obtener el area de un poligono
        irregular
    """
    return 0.5 * np.abs(np.dot(x, np.roll(y, 1)) - np.dot(y, np.roll(x, 1)))


def create_anotation(json_file, img_id, categoria):
    """ A partir de un JSON con formato de origen se obtiene una anotacion para
        insertar en el archivo general
    """
    anotation = dict()
    # Harcodeada la busqueda de los atributos, se puede flexibilizar
    for elem in json_file.items():
        x_vals = elem[1]["regions"][0]["shape_attributes"]["all_points_x"]
        y_vals = elem[1]["regions"][0]["shape_attributes"]["all_points_y"]
    anotation["segmentation"] = gen_segmentation(x_vals, y_vals)
    anotation["bbox"] = gen_bbox(x_vals, y_vals)
    anotation["area"] = gen_area(x_vals, y_vals)
    # Id como timestamp para no tener que tener en cuenta la anterior
    anotation["id"] = str(img_id)+"_"+str(categoria)
    # Nunca se va a fragmentar un diente / raiz en una radigrafia
    anotation["iscrowd"] = 0
    anotation["image_id"] = img_id
    # 0 es diente, 1 es raiz TODO: corregir
    anotation["category_id"] = categoria
    return anotation

# %%
def create_image(img_path, img_id, license=0):
    """ Crea una entrada de imgen para introducir en el json COCO
    """
    img = dict()
    img_load = cv2.imread(img_path)
    img["id"] = img_id
    img["license"] = license
    img["file_name"] = img_path.split("/")[-1]
    img["height"] = img_load.shape[0]
    img["width"] = img_load.shape[1]
    return img


def copy_image(img_path, destination):
    shutil.copyfile(img_path, destination)

# %%
def generar_COCOjson(lista_trios, COCOjson):
    """ A partir de una lista de trios (diccionario) tal que
        {"imagen":,"json_diente":,"json_raiz":}
        genera entradas de imagen y anotacion para el cocoo
    """
    index = 0
    for trio in lista_trios:
        entrada_imagen = create_image(
            img_path=trio["imagen"].path,
            img_id=index,
            license=0
        )
        copy_image(trio["imagen"].path, (img_folder+trio["imagen"].name))

        with open(trio["json_diente"].path) as diente:
            j_diente = json.load(diente)
            anot_diente = create_anotation(
                json_file=j_diente,
                img_id=index,
                categoria=0
            )

        with open(trio["json_raiz"].path) as raiz:
            j_raiz = json.load(raiz)
            anot_raiz = create_anotation(
                json_file=j_raiz,
                img_id=index,
                categoria=1
            )

        COCOjson["images"].append(entrada_imagen)
        COCOjson["annotations"].append(anot_diente)
        COCOjson["annotations"].append(anot_raiz)
        index += 1
    return COCOjson

# %%
# Se eliminan las imagenes previas
shutil.rmtree(org_folder)
os.mkdir(org_folder)

# Se abre el archivo COCO de plantilla
with open(coco_file) as file:
    data = json.load(file)
    final = generar_COCOjson(
        lista_trios=lee_subcarpetas(raw_folder), 
        COCOjson=data
    )

# Se escribe el json nuevo
with open("./Dataset/labels.json", "w+") as outfile:
    outfile.write(json.dumps(final, indent=5))
# Out:
# -> Accediendo a la capeta CASO 1
# 	 -> Analizando el elemento CASO1.TOOTH.json
# 		 -> introduciendo datos diente CASO1.TOOTH.json
# 	 -> Analizando el elemento 1A.jpg
# 		 -> introduciendo imagen 1A.jpg
# 	 -> Analizando el elemento 1B.jpg
# 	 -> Analizando el elemento CASO 1.ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 1.ROOT CANAL.json
# 	 #En el directorio CASO 1 hay 3 elementos
# -> Accediendo a la capeta CASO 16
# 	 -> Analizando el elemento 16b.jpg
# 	 -> Analizando el elemento CASO 16. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 16. ROOT CANAL.json
# 	 -> Analizando el elemento 16a.jpg
# 		 -> introduciendo imagen 16a.jpg
# 	 -> Analizando el elemento CASO 16. TOOTH.json
# 		 -> introduciendo datos diente CASO 16. TOOTH.json
# 	 #En el directorio CASO 16 hay 3 elementos
# -> Accediendo a la capeta CASO 30
# 	 -> Analizando el elemento CASO 30. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 30. ROOT CANAL.json
# 	 -> Analizando el elemento CASO 30. TOOTH.json
# 		 -> introduciendo datos diente CASO 30. TOOTH.json
# 	 -> Analizando el elemento 30b.jpg
# 	 -> Analizando el elemento 30a.jpg
# 		 -> introduciendo imagen 30a.jpg
# 	 #En el directorio CASO 30 hay 3 elementos
# -> Accediendo a la capeta CASO 8
# 	 -> Analizando el elemento CASO 8. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 8. ROOT CANAL.json
# 	 -> Analizando el elemento 8a.jpg
# 		 -> introduciendo imagen 8a.jpg
# 	 -> Analizando el elemento CASO 8. TOOTH.json
# 		 -> introduciendo datos diente CASO 8. TOOTH.json
# 	 -> Analizando el elemento 8b.jpg
# 	 #En el directorio CASO 8 hay 3 elementos
# -> Accediendo a la capeta CASO 33
# 	 -> Analizando el elemento CASO 33. TOOTH.json
# 		 -> introduciendo datos diente CASO 33. TOOTH.json
# 	 -> Analizando el elemento 33A.jpg
# 		 -> introduciendo imagen 33A.jpg
# 	 -> Analizando el elemento CASO 33. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 33. ROOT CANAL.json
# 	 -> Analizando el elemento 33B.jpg
# 	 #En el directorio CASO 33 hay 3 elementos
# -> Accediendo a la capeta CASO 48
# 	 -> Analizando el elemento CASO 48. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 48. ROOT CANAL.json
# 	 -> Analizando el elemento CASO 48. TOOTH.json
# 		 -> introduciendo datos diente CASO 48. TOOTH.json
# 	 -> Analizando el elemento 48A.jpg
# 		 -> introduciendo imagen 48A.jpg
# 	 -> Analizando el elemento 48B.jpg
# 	 #En el directorio CASO 48 hay 3 elementos
# -> Accediendo a la capeta CASO 10
# 	 -> Analizando el elemento 10b.jpg
# 	 -> Analizando el elemento CASO 10. TOOTH.json
# 		 -> introduciendo datos diente CASO 10. TOOTH.json
# 	 -> Analizando el elemento 10a.jpg
# 		 -> introduciendo imagen 10a.jpg
# 	 -> Analizando el elemento CASO 10. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 10. ROOT CANAL.json
# 	 #En el directorio CASO 10 hay 3 elementos
# -> Accediendo a la capeta CASO 53
# 	 -> Analizando el elemento CASO 53. TOOTH.json
# 		 -> introduciendo datos diente CASO 53. TOOTH.json
# 	 -> Analizando el elemento 53B.jpg
# 	 -> Analizando el elemento 53A.jpg
# 		 -> introduciendo imagen 53A.jpg
# 	 -> Analizando el elemento CASO 53. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 53. ROOT CANAL.json
# 	 #En el directorio CASO 53 hay 3 elementos
# -> Accediendo a la capeta CASO 36
# 	 -> Analizando el elemento 36A.jpg
# 		 -> introduciendo imagen 36A.jpg
# 	 -> Analizando el elemento 36B.jpg
# 	 -> Analizando el elemento CASO 36. TOOTH.json
# 		 -> introduciendo datos diente CASO 36. TOOTH.json
# 	 #En el directorio CASO 36 hay 2 elementos
# 	!!! Faltan archivos
# -> Accediendo a la capeta CASO 27
# 	 -> Analizando el elemento 27a.jpg
# 		 -> introduciendo imagen 27a.jpg
# 	 -> Analizando el elemento 27b.jpg
# 	 -> Analizando el elemento CASO 27. TOOTH.json
# 		 -> introduciendo datos diente CASO 27. TOOTH.json
# 	 -> Analizando el elemento CASO 27. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 27. ROOT CANAL.json
# 	 #En el directorio CASO 27 hay 3 elementos
# -> Accediendo a la capeta CASO 52
# 	 -> Analizando el elemento CASO 52. TOOTH.json
# 		 -> introduciendo datos diente CASO 52. TOOTH.json
# 	 -> Analizando el elemento CASO 52. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 52. ROOT CANAL.json
# 	 -> Analizando el elemento 52A.jpg
# 		 -> introduciendo imagen 52A.jpg
# 	 -> Analizando el elemento 52B.jpg
# 	 #En el directorio CASO 52 hay 3 elementos
# -> Accediendo a la capeta CASO 29
# 	 -> Analizando el elemento CASO 29. TOOTH.json
# 		 -> introduciendo datos diente CASO 29. TOOTH.json
# 	 -> Analizando el elemento 29a.jpg
# 		 -> introduciendo imagen 29a.jpg
# 	 -> Analizando el elemento 29b.jpg
# 	 -> Analizando el elemento CASO 29. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 29. ROOT CANAL.json
# 	 #En el directorio CASO 29 hay 3 elementos
# -> Accediendo a la capeta CASO 22
# 	 -> Analizando el elemento 22B.jpg
# 	 -> Analizando el elemento CASO 33. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 33. ROOT CANAL.json
# 	 -> Analizando el elemento 22A.jpg
# 		 -> introduciendo imagen 22A.jpg
# 	 -> Analizando el elemento CASO 22. TOOTH.json
# 		 -> introduciendo datos diente CASO 22. TOOTH.json
# 	 #En el directorio CASO 22 hay 3 elementos
# -> Accediendo a la capeta CASO 14
# 	 -> Analizando el elemento 14b.jpg
# 	 -> Analizando el elemento 14a.jpg
# 		 -> introduciendo imagen 14a.jpg
# 	 -> Analizando el elemento CASO 14. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 14. ROOT CANAL.json
# 	 -> Analizando el elemento CASO 14. TOOTH.json
# 		 -> introduciendo datos diente CASO 14. TOOTH.json
# 	 #En el directorio CASO 14 hay 3 elementos
# -> Accediendo a la capeta CASO 51
# 	 -> Analizando el elemento 51A.jpg
# 		 -> introduciendo imagen 51A.jpg
# 	 -> Analizando el elemento CASO 51. TOOTH.json
# 		 -> introduciendo datos diente CASO 51. TOOTH.json
# 	 -> Analizando el elemento CASO 51. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 51. ROOT CANAL.json
# 	 -> Analizando el elemento 51B.jpg
# 	 #En el directorio CASO 51 hay 3 elementos
# -> Accediendo a la capeta CASO 6
# 	 -> Analizando el elemento CASO 6. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 6. ROOT CANAL.json
# 	 -> Analizando el elemento 6a.jpg
# 		 -> introduciendo imagen 6a.jpg
# 	 -> Analizando el elemento CASO 6. TOOTH.json
# 		 -> introduciendo datos diente CASO 6. TOOTH.json
# 	 -> Analizando el elemento 6b.jpg
# 	 #En el directorio CASO 6 hay 3 elementos
# -> Accediendo a la capeta CASO 50
# 	 -> Analizando el elemento 50B.jpg
# 	 -> Analizando el elemento CASO 50. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 50. ROOT CANAL.json
# 	 -> Analizando el elemento CASO 50. TOOTH.json
# 		 -> introduciendo datos diente CASO 50. TOOTH.json
# 	 -> Analizando el elemento 50A.jpg
# 		 -> introduciendo imagen 50A.jpg
# 	 #En el directorio CASO 50 hay 3 elementos
# -> Accediendo a la capeta CASO 24
# 	 -> Analizando el elemento CASO 24. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 24. ROOT CANAL.json
# 	 -> Analizando el elemento CASO 24. TOOTH.json
# 		 -> introduciendo datos diente CASO 24. TOOTH.json
# 	 -> Analizando el elemento 24A.jpg
# 		 -> introduciendo imagen 24A.jpg
# 	 -> Analizando el elemento 24B.jpg
# 	 #En el directorio CASO 24 hay 3 elementos
# -> Accediendo a la capeta CASO 5
# 	 -> Analizando el elemento 5a.jpg
# 		 -> introduciendo imagen 5a.jpg
# 	 -> Analizando el elemento CASO 5. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 5. ROOT CANAL.json
# 	 -> Analizando el elemento 5b.jpg
# 	 -> Analizando el elemento CASO 5. TOOTH.json
# 		 -> introduciendo datos diente CASO 5. TOOTH.json
# 	 #En el directorio CASO 5 hay 3 elementos
# -> Accediendo a la capeta CASO 42
# 	 -> Analizando el elemento CASO 42. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 42. ROOT CANAL.json
# 	 -> Analizando el elemento 42B.jpg
# 	 -> Analizando el elemento CASO 42. TOOTH.json
# 		 -> introduciendo datos diente CASO 42. TOOTH.json
# 	 -> Analizando el elemento 42A.jpg
# 		 -> introduciendo imagen 42A.jpg
# 	 #En el directorio CASO 42 hay 3 elementos
# -> Accediendo a la capeta CASO 17
# 	 -> Analizando el elemento CASO 17. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 17. ROOT CANAL.json
# 	 -> Analizando el elemento 17a.jpg
# 		 -> introduciendo imagen 17a.jpg
# 	 -> Analizando el elemento 17b.jpg
# 	 -> Analizando el elemento CASO 17. TOOTH.json
# 		 -> introduciendo datos diente CASO 17. TOOTH.json
# 	 #En el directorio CASO 17 hay 3 elementos
# -> Accediendo a la capeta CASO 9
# 	 -> Analizando el elemento 9a.jpg
# 		 -> introduciendo imagen 9a.jpg
# 	 -> Analizando el elemento CASO 9. TOOTH.json
# 		 -> introduciendo datos diente CASO 9. TOOTH.json
# 	 -> Analizando el elemento CASO 9. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 9. ROOT CANAL.json
# 	 -> Analizando el elemento 9b.jpg
# 	 -> Analizando el elemento 9c.jpg
# 	 #En el directorio CASO 9 hay 3 elementos
# -> Accediendo a la capeta CASO 38
# 	 -> Analizando el elemento CASO 38. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 38. ROOT CANAL.json
# 	 -> Analizando el elemento CASO 38. TOOTH.json
# 		 -> introduciendo datos diente CASO 38. TOOTH.json
# 	 -> Analizando el elemento 38A.jpg
# 		 -> introduciendo imagen 38A.jpg
# 	 -> Analizando el elemento 38B.jpg
# 	 #En el directorio CASO 38 hay 3 elementos
# -> Accediendo a la capeta CASO 21
# 	 -> Analizando el elemento 20 Y 21B.jpg
# 	 -> Analizando el elemento CASO 21. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 21. ROOT CANAL.json
# 	 -> Analizando el elemento 20 Y 21A.jpg
# 		 -> introduciendo imagen 20 Y 21A.jpg
# 	 -> Analizando el elemento CASO 21. TOOTH.json
# 		 -> introduciendo datos diente CASO 21. TOOTH.json
# 	 #En el directorio CASO 21 hay 3 elementos
# -> Accediendo a la capeta CASO 49
# 	 -> Analizando el elemento 49A.jpg
# 		 -> introduciendo imagen 49A.jpg
# 	 -> Analizando el elemento CASO 49. TOOTH.json
# 		 -> introduciendo datos diente CASO 49. TOOTH.json
# 	 -> Analizando el elemento 49B.jpg
# 	 -> Analizando el elemento CASO 49. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 49. ROOT CANAL.json
# 	 #En el directorio CASO 49 hay 3 elementos
# -> Accediendo a la capeta CASO 41
# 	 -> Analizando el elemento 41B.jpg
# 	 -> Analizando el elemento 41A.jpg
# 		 -> introduciendo imagen 41A.jpg
# 	 -> Analizando el elemento CASO 41. TOOTH.json
# 		 -> introduciendo datos diente CASO 41. TOOTH.json
# 	 -> Analizando el elemento CASO 41. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 41. ROOT CANAL.json
# 	 #En el directorio CASO 41 hay 3 elementos
# -> Accediendo a la capeta CASO 4
# 	 -> Analizando el elemento CASO 4. TOOTH.json
# 		 -> introduciendo datos diente CASO 4. TOOTH.json
# 	 -> Analizando el elemento 4a.jpg
# 		 -> introduciendo imagen 4a.jpg
# 	 -> Analizando el elemento 4b.jpg
# 	 -> Analizando el elemento CASO 4. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 4. ROOT CANAL.json
# 	 #En el directorio CASO 4 hay 3 elementos
# -> Accediendo a la capeta CASO 23
# 	 -> Analizando el elemento CASO 23. TOOTH.json
# 		 -> introduciendo datos diente CASO 23. TOOTH.json
# 	 -> Analizando el elemento 23A.jpg
# 		 -> introduciendo imagen 23A.jpg
# 	 -> Analizando el elemento 23B.jpg
# 	 -> Analizando el elemento CASO 23. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 23. ROOT CANAL.json
# 	 #En el directorio CASO 23 hay 3 elementos
# -> Accediendo a la capeta CASO 45
# 	 -> Analizando el elemento 45B.jpg
# 	 -> Analizando el elemento 45A.jpg
# 		 -> introduciendo imagen 45A.jpg
# 	 -> Analizando el elemento CASO 45. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 45. ROOT CANAL.json
# 	 -> Analizando el elemento CASO 45. TOOTH.json
# 		 -> introduciendo datos diente CASO 45. TOOTH.json
# 	 #En el directorio CASO 45 hay 3 elementos
# -> Accediendo a la capeta CASO 43
# 	 -> Analizando el elemento CASO 43. TOOTH.json
# 		 -> introduciendo datos diente CASO 43. TOOTH.json
# 	 -> Analizando el elemento 43A.jpg
# 		 -> introduciendo imagen 43A.jpg
# 	 -> Analizando el elemento CASO 43. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 43. ROOT CANAL.json
# 	 -> Analizando el elemento 43B.jpg
# 	 #En el directorio CASO 43 hay 3 elementos
# -> Accediendo a la capeta CASO 34
# 	 -> Analizando el elemento 34B.jpg
# 	 -> Analizando el elemento 34A.jpg
# 		 -> introduciendo imagen 34A.jpg
# 	 -> Analizando el elemento CASO 34. TOOTH.json
# 		 -> introduciendo datos diente CASO 34. TOOTH.json
# 	 -> Analizando el elemento CASO 34. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 34. ROOT CANAL.json
# 	 #En el directorio CASO 34 hay 3 elementos
# -> Accediendo a la capeta CASO 12
# 	 -> Analizando el elemento 12b.jpg
# 	 -> Analizando el elemento 12a.jpg
# 		 -> introduciendo imagen 12a.jpg
# 	 -> Analizando el elemento CASO 12. TOOTH.json
# 		 -> introduciendo datos diente CASO 12. TOOTH.json
# 	 -> Analizando el elemento CASO 12. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 12. ROOT CANAL.json
# 	 #En el directorio CASO 12 hay 3 elementos
# -> Accediendo a la capeta CASO 39
# 	 -> Analizando el elemento 39A.jpg
# 		 -> introduciendo imagen 39A.jpg
# 	 -> Analizando el elemento 39B.jpg
# 	 -> Analizando el elemento CASO 39. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 39. ROOT CANAL.json
# 	 -> Analizando el elemento CASO 39. TOOTH.json
# 		 -> introduciendo datos diente CASO 39. TOOTH.json
# 	 #En el directorio CASO 39 hay 3 elementos
# -> Accediendo a la capeta CASO 13
# 	 -> Analizando el elemento CASO 13. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 13. ROOT CANAL.json
# 	 -> Analizando el elemento CASO 13. TOOTH.json
# 		 -> introduciendo datos diente CASO 13. TOOTH.json
# 	 -> Analizando el elemento 13.jpg
# 		 -> introduciendo imagen 13.jpg
# 	 #En el directorio CASO 13 hay 3 elementos
# -> Accediendo a la capeta CASO 37
# 	 -> Analizando el elemento CASO 37. TOOTH.json
# 		 -> introduciendo datos diente CASO 37. TOOTH.json
# 	 -> Analizando el elemento CASO 37. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 37. ROOT CANAL.json
# 	 -> Analizando el elemento 37B.jpg
# 	 -> Analizando el elemento 37A.jpg
# 		 -> introduciendo imagen 37A.jpg
# 	 #En el directorio CASO 37 hay 3 elementos
# -> Accediendo a la capeta CASO 11
# 	 -> Analizando el elemento 11b.jpg
# 	 -> Analizando el elemento CASO 11. TOOTH.json
# 		 -> introduciendo datos diente CASO 11. TOOTH.json
# 	 -> Analizando el elemento CASO 11. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 11. ROOT CANAL.json
# 	 -> Analizando el elemento 11a.jpg
# 		 -> introduciendo imagen 11a.jpg
# 	 #En el directorio CASO 11 hay 3 elementos
# -> Accediendo a la capeta CASO 47
# 	 -> Analizando el elemento CASO 47. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 47. ROOT CANAL.json
# 	 -> Analizando el elemento 47A.jpg
# 		 -> introduciendo imagen 47A.jpg
# 	 -> Analizando el elemento 47B.jpg
# 	 -> Analizando el elemento CASO 47. TOOTH.json
# 		 -> introduciendo datos diente CASO 47. TOOTH.json
# 	 #En el directorio CASO 47 hay 3 elementos
# -> Accediendo a la capeta CASO 44
# 	 -> Analizando el elemento CASO 44. TOOTH.json
# 		 -> introduciendo datos diente CASO 44. TOOTH.json
# 	 -> Analizando el elemento 44A.jpg
# 		 -> introduciendo imagen 44A.jpg
# 	 -> Analizando el elemento 44B.jpg
# 	 -> Analizando el elemento CASO 44. ROOT CANAL.json
# 		 -> introduciendo datos raiz CASO 44. ROOT CANAL.json
# 	 #En el directorio CASO 44 hay 3 elementos
# # Se han analizado 37 diretorios validos
